# %% [markdown]
# <a href="https://colab.research.google.com/github/shivania-network/25rp19281/blob/main/aiml03_l1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install otter-grader


import otter
import zipfile
import urllib.request
import os

url = "https://gist.githubusercontent.com/CMU-Africa/ac0b8eafd27a355473f96a2a700d1149/raw/tests.zip"
urllib.request.urlretrieve(url, "tests.zip")
with zipfile.ZipFile("tests.zip", 'r') as zip_ref:
    zip_ref.extractall()
# Initialize Otter
grader = otter.Notebook()  # Assigns it this notebook
print("Setup complete!")
# Out:
# ...
# Setup complete!

# %% [markdown]
# **Question 1**
#
# Do some searching and review these:
#
# 1.   [Overview of Colaboratory Features](https://colab.research.google.com/notebooks/basic_features_overview.ipynb)
# 2.   [Code Editing Help](https://www.tutorialspoint.com/google_colab/google_colab_code_editing.htm) from tutorialspoint.com
#
# Then update the questions below to print the answers by assigning each answer to its respective variable.

# %%
A1 = "code"
A2 = "text"
A3 = "double-click"
A4 = "/"
A5 = "/"
A6 = "tab"
A7 = "shift-tab"
A8 = "up or down"
A9 = "editor"

# %%
print (f"The 2 types of cells are {A1} and {A2}")
print (f"To edit a text cell you should {A3} in the cell")
print (f"The shortcut to comment-out code is to highlight it then press CTRL- or CMD- {A4}.")
print (f"The shortcut to un-comment-out code is to highlight the code that starts with #, then press CTRL- or CMD- {A5}.")
print (f"To indent a block of code, you can highlight it then press the {A6} key.")
print (f"To un-indent a block of code, you can highlight it then press {A7}.")
print (f"To move a cell, select it then press the {A8} in the floating toolbar")
print (f"To show line numbers, select {A9} from the Settings Wheel and then click on Show line numbers.")
# Out:
# The 2 types of cells are code and text
# To edit a text cell you should double-click in the cell
# The shortcut to comment-out code is to highlight it then press CTRL- or CMD- /.
# The shortcut to un-comment-out code is to highlight the code that starts with #, then press CTRL- or CMD- /.
# To indent a block of code, you can highlight it then press the tab key.
# To un-indent a block of code, you can highlight it then press shift-tab.
# To move a cell, select it then press the up or down in the floating toolbar
# To show line numbers, select editor from the Settings Wheel and then click on Show line numbers.

# %%
grader.check("q1")

# %% [markdown]
# ---
# # **Question 2**
#
# Fix the errors in the following code; see if you can spot them all before trying to run!

# %%
a = prompt("Enter a:')
  b = prompt('Enter b:

if (a > b)
print 'a:', a, 'is bigger!'
elif (b > a
    print (''b:', b 'is bigger!')
    else
      print 'a and b are equal'
      print ()'done!'

# %%
a = input("Enter a: ")
b = input("Enter b: ")

if (a > b):
    print('a:', a, 'is bigger!')
elif (b > a):
    print('b:', b, 'is bigger!')
else:
    print('a and b are equal')

print('done!')
# Out:
# Enter a: 23
# Enter b: 34
# b: 34 is bigger!
# done!

# %% [markdown]
# ---
# # **Question 3**
# Open a code block below and add this code:
#
# ```
# a = True
# b = false
# if (a):
#    print('a is true!')
# if (b):
#    print('b is true!')
# ```
#  Think before running it, does it give you the output you expect? If not, fix any error(s).

# %% [markdown]
# Next, add the code shown below.
#
# Again think about what you expect to see as the result
#
# ![Screen Shot 2025-07-10 at 3.21.34 PM.png](data:image/png;base64,...)
# Did you get the expected output?

# %%
a = True
b = False

if (a):
    print('a is true!')

if (b):
    print('b is true!')

q = 5

if (q > 3):
    print("q is bigger than 3")
# Out:
# a is true!
# q is bigger than 3

# %% [markdown]
# ---
#
# To double-check your work, the cell below will rerun all of the autograder tests.

# %%
grader.check_all()
# Out:
# q1 results: All test cases passed!
